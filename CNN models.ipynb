# %% [markdown]
# ###Importing Required Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
import matplotlib.pyplot as plt
from keras import layers
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist

# %% [markdown]
# ### PreProcessing The Data

# %%
dataset = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = dataset.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
#x_train = x_train.reshape(60000, 784)
#x_test = x_test.reshape(10000, 784)

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
#y_valid = tf.keras.utils.to_categorical(y_valid, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
y_train.shape
# Out:
# (60000, 10)

# %% [markdown]
# ###New Model 1 Relu

# %%
model_6 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_6.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_6 = model_6.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 15s 7ms/step - loss: 0.5187 - accuracy: 0.8184 - val_loss: 0.4069 - val_accuracy: 0.8569
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3856 - accuracy: 0.8623 - val_loss: 0.3868 - val_accuracy: 0.8615
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3444 - accuracy: 0.8749 - val_loss: 0.3495 - val_accuracy: 0.8711
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3203 - accuracy: 0.8833 - val_loss: 0.3749 - val_accuracy: 0.8594
# Epoch 5/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3009 - accuracy: 0.8898 - val_loss: 0.3483 - val_accuracy: 0.8750
# Epoch 6/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2842 - accuracy: 0.8941 - val_loss: 0.3214 - val_accuracy: 0.8850
# Epoch 7/10
# ...

# %%
plt.plot(history_6.history['loss'])
plt.plot(history_6.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New model 2 Relu

# %%
model_7 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_7.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_7 = model_7.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5347 - accuracy: 0.8102 - val_loss: 0.4454 - val_accuracy: 0.8397
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3858 - accuracy: 0.8600 - val_loss: 0.3894 - val_accuracy: 0.8587
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3460 - accuracy: 0.8729 - val_loss: 0.3772 - val_accuracy: 0.8657
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3240 - accuracy: 0.8805 - val_loss: 0.3437 - val_accuracy: 0.8776
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3047 - accuracy: 0.8873 - val_loss: 0.3427 - val_accuracy: 0.8752
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2886 - accuracy: 0.8922 - val_loss: 0.3230 - val_accuracy: 0.8823
# Epoch 7/10
# ...

# %%
plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 3 Relu

# %%
model_8 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1024, activation=tf.nn.relu),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(256, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_8.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_8 = model_8.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 15s 9ms/step - loss: 0.5951 - accuracy: 0.7862 - val_loss: 0.4634 - val_accuracy: 0.8403
# Epoch 2/10
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.4083 - accuracy: 0.8517 - val_loss: 0.4342 - val_accuracy: 0.8359
# Epoch 3/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3666 - accuracy: 0.8688 - val_loss: 0.3681 - val_accuracy: 0.8672
# Epoch 4/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.3411 - accuracy: 0.8768 - val_loss: 0.3549 - val_accuracy: 0.8727
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3171 - accuracy: 0.8850 - val_loss: 0.3514 - val_accuracy: 0.8748
# Epoch 6/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.2999 - accuracy: 0.8904 - val_loss: 0.3398 - val_accuracy: 0.8827
# Epoch 7/10
# ...

# %%
plt.plot(history_8.history['loss'])
plt.plot(history_8.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 1 Sigmoid

# %%
model_s_1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.sigmoid),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_s_1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_s_1 = model_s_1.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.5701 - accuracy: 0.8051 - val_loss: 0.4325 - val_accuracy: 0.8415
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.4041 - accuracy: 0.8543 - val_loss: 0.4020 - val_accuracy: 0.8535
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3672 - accuracy: 0.8677 - val_loss: 0.3798 - val_accuracy: 0.8622
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3407 - accuracy: 0.8779 - val_loss: 0.3703 - val_accuracy: 0.8643
# Epoch 5/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3206 - accuracy: 0.8836 - val_loss: 0.3364 - val_accuracy: 0.8783
# Epoch 6/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3057 - accuracy: 0.8883 - val_loss: 0.3343 - val_accuracy: 0.8791
# Epoch 7/10
# ...

# %%
plt.plot(history_s_1.history['loss'])
plt.plot(history_s_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 2 Sigmoid

# %%
model_s_2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.sigmoid),
    keras.layers.Dense(64, activation=tf.nn.sigmoid),
    keras.layers.Dense(32, activation=tf.nn.sigmoid),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_s_2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_s_2 = model_s_2.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.8506 - accuracy: 0.7297 - val_loss: 0.4850 - val_accuracy: 0.8331
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4296 - accuracy: 0.8508 - val_loss: 0.4218 - val_accuracy: 0.8471
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3756 - accuracy: 0.8685 - val_loss: 0.3721 - val_accuracy: 0.8694
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3469 - accuracy: 0.8783 - val_loss: 0.3491 - val_accuracy: 0.8735
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3258 - accuracy: 0.8831 - val_loss: 0.3456 - val_accuracy: 0.8773
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3082 - accuracy: 0.8898 - val_loss: 0.3392 - val_accuracy: 0.8796
# Epoch 7/10
# ...

# %%
plt.plot(history_s_2.history['loss'])
plt.plot(history_s_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 3 Sigmoid

# %%
model_s_3 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1024, activation=tf.nn.sigmoid),
    keras.layers.Dense(512, activation=tf.nn.sigmoid),
    keras.layers.Dense(256, activation=tf.nn.sigmoid),
    keras.layers.Dense(128, activation=tf.nn.sigmoid),
    keras.layers.Dense(64, activation=tf.nn.sigmoid),
    keras.layers.Dense(32, activation=tf.nn.sigmoid),
    keras.layers.Dense(16, activation=tf.nn.sigmoid),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_s_3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_s_3 = model_s_3.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 1.6611 - accuracy: 0.3948 - val_loss: 1.1714 - val_accuracy: 0.6253
# Epoch 2/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.8144 - accuracy: 0.7239 - val_loss: 0.6765 - val_accuracy: 0.7479
# Epoch 3/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.6109 - accuracy: 0.7643 - val_loss: 0.5536 - val_accuracy: 0.8246
# Epoch 4/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4935 - accuracy: 0.8420 - val_loss: 0.4733 - val_accuracy: 0.8504
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4284 - accuracy: 0.8620 - val_loss: 0.4351 - val_accuracy: 0.8553
# Epoch 6/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3999 - accuracy: 0.8711 - val_loss: 0.3934 - val_accuracy: 0.8723
# Epoch 7/10
# ...

# %%
plt.plot(history_s_3.history['loss'])
plt.plot(history_s_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 1 tanh

# %%
model_t_1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.tanh),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_t_1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_t_1 = model_t_1.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4963 - accuracy: 0.8224 - val_loss: 0.3973 - val_accuracy: 0.8561
# Epoch 2/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3789 - accuracy: 0.8621 - val_loss: 0.3802 - val_accuracy: 0.8608
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3442 - accuracy: 0.8736 - val_loss: 0.3542 - val_accuracy: 0.8717
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3201 - accuracy: 0.8824 - val_loss: 0.3405 - val_accuracy: 0.8760
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2994 - accuracy: 0.8905 - val_loss: 0.3359 - val_accuracy: 0.8776
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2860 - accuracy: 0.8940 - val_loss: 0.3392 - val_accuracy: 0.8752
# Epoch 7/10
# ...

# %%
plt.plot(history_t_1.history['loss'])
plt.plot(history_t_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 2 tanh

# %%
model_t_2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.tanh),
    keras.layers.Dense(64, activation=tf.nn.tanh),
    keras.layers.Dense(32, activation=tf.nn.tanh),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_t_2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_t_2 = model_t_2.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5049 - accuracy: 0.8225 - val_loss: 0.4402 - val_accuracy: 0.8375
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3766 - accuracy: 0.8631 - val_loss: 0.3851 - val_accuracy: 0.8618
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3463 - accuracy: 0.8735 - val_loss: 0.3689 - val_accuracy: 0.8610
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3204 - accuracy: 0.8817 - val_loss: 0.3455 - val_accuracy: 0.8715
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3030 - accuracy: 0.8880 - val_loss: 0.3536 - val_accuracy: 0.8706
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2929 - accuracy: 0.8905 - val_loss: 0.3696 - val_accuracy: 0.8639
# Epoch 7/10
# ...

# %%
plt.plot(history_t_2.history['loss'])
plt.plot(history_t_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 3 tanh

# %%
model_t_3 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1024, activation=tf.nn.tanh),
    keras.layers.Dense(512, activation=tf.nn.tanh),
    keras.layers.Dense(256, activation=tf.nn.tanh),
    keras.layers.Dense(128, activation=tf.nn.tanh),
    keras.layers.Dense(64, activation=tf.nn.tanh),
    keras.layers.Dense(32, activation=tf.nn.tanh),
    keras.layers.Dense(16, activation=tf.nn.tanh),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_t_3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_t_3 = model_t_3.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.6323 - accuracy: 0.7890 - val_loss: 0.5077 - val_accuracy: 0.8227
# Epoch 2/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4627 - accuracy: 0.8376 - val_loss: 0.4633 - val_accuracy: 0.8384
# Epoch 3/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.4280 - accuracy: 0.8474 - val_loss: 0.4074 - val_accuracy: 0.8538
# Epoch 4/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4052 - accuracy: 0.8544 - val_loss: 0.4388 - val_accuracy: 0.8463
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3972 - accuracy: 0.8578 - val_loss: 0.4077 - val_accuracy: 0.8607
# Epoch 6/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3845 - accuracy: 0.8605 - val_loss: 0.3984 - val_accuracy: 0.8591
# Epoch 7/10
# ...

# %%
plt.plot(history_t_3.history['loss'])
plt.plot(history_t_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New_model_1_KL_Relu

# %%
model_r_kl_1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_r_kl_1.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_r_kl_1 = model_r_kl_1.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5724 - accuracy: 0.7978 - val_loss: 0.4218 - val_accuracy: 0.8518
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3943 - accuracy: 0.8591 - val_loss: 0.3752 - val_accuracy: 0.8633
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3556 - accuracy: 0.8705 - val_loss: 0.3672 - val_accuracy: 0.8621
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3309 - accuracy: 0.8780 - val_loss: 0.3524 - val_accuracy: 0.8742
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3129 - accuracy: 0.8829 - val_loss: 0.3763 - val_accuracy: 0.8712
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2975 - accuracy: 0.8908 - val_loss: 0.3346 - val_accuracy: 0.8831
# Epoch 7/10
# ...

# %%
plt.plot(history_r_kl_1.history['loss'])
plt.plot(history_r_kl_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %%
plt.plot(history_r_kl_1.history['loss'])
plt.plot(history_7.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['r_kl_1', 'cross entropy'], loc='upper left')
plt.show()

# %% [markdown]
# ###KL 2 Relu

# %%
model_r_kl_2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1024, activation=tf.nn.relu),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(256, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_r_kl_2.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_r_kl_2 = model_r_kl_2.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.5777 - accuracy: 0.7918 - val_loss: 0.4857 - val_accuracy: 0.8282
# Epoch 2/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4092 - accuracy: 0.8531 - val_loss: 0.4199 - val_accuracy: 0.8548
# Epoch 3/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3649 - accuracy: 0.8680 - val_loss: 0.3917 - val_accuracy: 0.8692
# Epoch 4/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3367 - accuracy: 0.8781 - val_loss: 0.3728 - val_accuracy: 0.8694
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3170 - accuracy: 0.8835 - val_loss: 0.3491 - val_accuracy: 0.8828
# Epoch 6/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3005 - accuracy: 0.8915 - val_loss: 0.3669 - val_accuracy: 0.8726
# Epoch 7/10
# ...

# %%
plt.plot(history_r_kl_2.history['loss'])
plt.plot(history_r_kl_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New_model_1_KL_Sigmoid

# %%
model_s_kl_1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.sigmoid),
    keras.layers.Dense(64, activation=tf.nn.sigmoid),
    keras.layers.Dense(32, activation=tf.nn.sigmoid),
    keras.layers.Dense(16, activation=tf.nn.sigmoid),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_s_kl_1.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_s_kl_1 = model_s_kl_1.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 1.2348 - accuracy: 0.5648 - val_loss: 0.8069 - val_accuracy: 0.6607
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.6740 - accuracy: 0.7673 - val_loss: 0.5662 - val_accuracy: 0.8221
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4628 - accuracy: 0.8518 - val_loss: 0.4247 - val_accuracy: 0.8595
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3948 - accuracy: 0.8674 - val_loss: 0.4050 - val_accuracy: 0.8619
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3597 - accuracy: 0.8779 - val_loss: 0.3807 - val_accuracy: 0.8668
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3366 - accuracy: 0.8846 - val_loss: 0.3599 - val_accuracy: 0.8763
# Epoch 7/10
# ...

# %%
plt.plot(history_s_kl_1.history['loss'])
plt.plot(history_s_kl_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model Sigmoid KL 2

# %%
model_s_kl_2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1024, activation=tf.nn.sigmoid),
    keras.layers.Dense(512, activation=tf.nn.sigmoid),
    keras.layers.Dense(256, activation=tf.nn.sigmoid),
    keras.layers.Dense(128, activation=tf.nn.sigmoid),
    keras.layers.Dense(64, activation=tf.nn.sigmoid),
    keras.layers.Dense(32, activation=tf.nn.sigmoid),
    keras.layers.Dense(16, activation=tf.nn.sigmoid),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_s_kl_2.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_s_kl_2 = model_s_kl_2.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 1.8804 - accuracy: 0.1814 - val_loss: 1.7223 - val_accuracy: 0.1987
# Epoch 2/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 1.7249 - accuracy: 0.2003 - val_loss: 1.7180 - val_accuracy: 0.2015
# Epoch 3/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 1.7240 - accuracy: 0.1978 - val_loss: 1.7242 - val_accuracy: 0.2013
# Epoch 4/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 1.6961 - accuracy: 0.2125 - val_loss: 1.5270 - val_accuracy: 0.2964
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 1.5025 - accuracy: 0.2985 - val_loss: 1.4197 - val_accuracy: 0.3652
# Epoch 6/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 1.3181 - accuracy: 0.4062 - val_loss: 1.1324 - val_accuracy: 0.4844
# Epoch 7/10
# ...

# %%
plt.plot(history_s_kl_2.history['loss'])
plt.plot(history_s_kl_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New_model_1_KL_TanH

# %%
model_t_kl_1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.tanh),
    keras.layers.Dense(64, activation=tf.nn.tanh),
    keras.layers.Dense(32, activation=tf.nn.tanh),
    keras.layers.Dense(16, activation=tf.nn.tanh),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_t_kl_1.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_t_kl_1 = model_t_kl_1.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.5592 - accuracy: 0.8165 - val_loss: 0.4173 - val_accuracy: 0.8504
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3967 - accuracy: 0.8597 - val_loss: 0.3829 - val_accuracy: 0.8637
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3574 - accuracy: 0.8726 - val_loss: 0.3641 - val_accuracy: 0.8663
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3398 - accuracy: 0.8766 - val_loss: 0.3813 - val_accuracy: 0.8669
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3233 - accuracy: 0.8825 - val_loss: 0.3442 - val_accuracy: 0.8777
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3087 - accuracy: 0.8869 - val_loss: 0.3964 - val_accuracy: 0.8559
# Epoch 7/10
# ...

# %%
plt.plot(history_t_kl_1.history['loss'])
plt.plot(history_t_kl_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 2 KL Tanh

# %%
model_t_kl_2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1024, activation=tf.nn.tanh),
    keras.layers.Dense(512, activation=tf.nn.tanh),
    keras.layers.Dense(256, activation=tf.nn.tanh),
    keras.layers.Dense(128, activation=tf.nn.tanh),
    keras.layers.Dense(64, activation=tf.nn.tanh),
    keras.layers.Dense(32, activation=tf.nn.tanh),
    keras.layers.Dense(16, activation=tf.nn.tanh),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_t_kl_2.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_t_kl_2 = model_t_kl_2.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.6440 - accuracy: 0.7831 - val_loss: 0.5270 - val_accuracy: 0.8195
# Epoch 2/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4734 - accuracy: 0.8353 - val_loss: 0.4429 - val_accuracy: 0.8457
# Epoch 3/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4362 - accuracy: 0.8466 - val_loss: 0.4145 - val_accuracy: 0.8516
# Epoch 4/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.4113 - accuracy: 0.8520 - val_loss: 0.4165 - val_accuracy: 0.8517
# Epoch 5/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.3947 - accuracy: 0.8598 - val_loss: 0.4037 - val_accuracy: 0.8569
# Epoch 6/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.3880 - accuracy: 0.8604 - val_loss: 0.4112 - val_accuracy: 0.8469
# Epoch 7/10
# ...

# %%
plt.plot(history_t_kl_2.history['loss'])
plt.plot(history_t_kl_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###New Model 3 KL Tanh

# %%
model_t_kl_3 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
   
    keras.layers.Dense(256, activation=tf.nn.tanh),
    keras.layers.Dense(128, activation=tf.nn.tanh),
    keras.layers.Dense(64, activation=tf.nn.tanh),
    keras.layers.Dense(32, activation=tf.nn.tanh),
    keras.layers.Dense(16, activation=tf.nn.tanh),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model_t_kl_3.compile(optimizer='adam',
              loss='kl_divergence',
              metrics=['accuracy'])

history_t_kl_3 = model_t_kl_3.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5727 - accuracy: 0.8156 - val_loss: 0.4400 - val_accuracy: 0.8447
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4102 - accuracy: 0.8560 - val_loss: 0.4008 - val_accuracy: 0.8612
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3714 - accuracy: 0.8675 - val_loss: 0.3662 - val_accuracy: 0.8696
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3527 - accuracy: 0.8717 - val_loss: 0.3584 - val_accuracy: 0.8760
# Epoch 5/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.3325 - accuracy: 0.8798 - val_loss: 0.3533 - val_accuracy: 0.8746
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3217 - accuracy: 0.8834 - val_loss: 0.3611 - val_accuracy: 0.8678
# Epoch 7/10
# ...

# %%
plt.plot(history_t_kl_3.history['loss'])
plt.plot(history_t_kl_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on loss function

# %%
plt.plot(history_7.history['accuracy'])
plt.plot(history_r_kl_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Crossentropy', 'KL'], loc='upper left')
plt.show()

# %%
plt.plot(history_8.history['accuracy'])
plt.plot(history_r_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Crossentropy', 'KL'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_2.history['accuracy'])
plt.plot(history_s_kl_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Crossentropy', 'KL'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_3.history['accuracy'])
plt.plot(history_s_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Crossentropy', 'KL'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_2.history['accuracy'])
plt.plot(history_t_kl_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Crossentropy', 'KL'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_3.history['accuracy'])
plt.plot(history_t_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Crossentropy', 'KL'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on number of layers in RELU using Categorical Crossentropy

# %%
plt.plot(history_6.history['accuracy'])
plt.plot(history_7.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer', '3 layers'], loc='upper left')
plt.show()

# %%
plt.plot(history_7.history['accuracy'])
plt.plot(history_8.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['3 layers', '7 layers'], loc='upper left')
plt.show()

# %%
plt.plot(history_6.history['accuracy'])
plt.plot(history_8.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer', '7 layers'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on number of layers in Sigmoid using Categorical Crossentropy

# %%
plt.plot(history_s_1.history['accuracy'])
plt.plot(history_s_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer', '3 layers'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_2.history['accuracy'])
plt.plot(history_s_3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['3 layers', '7 layers'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_1.history['accuracy'])
plt.plot(history_s_3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layers', '7 layer'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on number of layers in Tanh using Categorical Crossentropy

# %%
plt.plot(history_t_1.history['accuracy'])
plt.plot(history_t_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer', '3 layers'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_2.history['accuracy'])
plt.plot(history_t_3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['3 layers', '7 layers'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_1.history['accuracy'])
plt.plot(history_t_3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layers', '7 layer'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on number of layers in RELU using KL divergence

# %%
plt.plot(history_r_kl_1.history['accuracy'])
plt.plot(history_r_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['3 layer', '7 layers'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on number of layers in Sigmoid using KL divergence

# %%
plt.plot(history_s_kl_1.history['accuracy'])
plt.plot(history_s_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['3 layer', '7 layers'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on number of layers in Tanh using KL divergence

# %%
plt.plot(history_t_kl_1.history['accuracy'])
plt.plot(history_t_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['3 layer', '7 layers'], loc='upper left')
plt.show()

# %% [markdown]
# ###Comparision based on Activation Function using Categorical Crossentropy

# %%
plt.plot(history_6.history['accuracy'])
plt.plot(history_s_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['RELU', 'Sigmoid'], loc='upper left')
plt.show()

# %%
plt.plot(history_7.history['accuracy'])
plt.plot(history_s_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['RELU', 'Sigmoid'], loc='upper left')
plt.show()

# %%
plt.plot(history_8.history['accuracy'])
plt.plot(history_s_3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['RELU', 'Sigmoid'], loc='upper left')
plt.show()

# %%
plt.plot(history_r_kl_1.history['accuracy'])
plt.plot(history_s_kl_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['RELU', 'Sigmoid'], loc='upper left')
plt.show()

# %%
plt.plot(history_r_kl_2.history['accuracy'])
plt.plot(history_s_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['RELU', 'Sigmoid'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_1.history['accuracy'])
plt.plot(history_t_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sigmoid', 'Tanh'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_2.history['accuracy'])
plt.plot(history_t_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sigmoid', 'Tanh'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_3.history['accuracy'])
plt.plot(history_t_3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sigmoid', 'Tanh'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_kl_1.history['accuracy'])
plt.plot(history_t_kl_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sigmoid', 'Tanh'], loc='upper left')
plt.show()

# %%
plt.plot(history_s_kl_2.history['accuracy'])
plt.plot(history_t_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sigmoid', 'Tanh'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_1.history['accuracy'])
plt.plot(history_6.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Tanh', 'RELU'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_2.history['accuracy'])
plt.plot(history_7.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Tanh', 'RELU'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_3.history['accuracy'])
plt.plot(history_8.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Tanh', 'RELU'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_kl_1.history['accuracy'])
plt.plot(history_r_kl_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Tanh', 'RELU'], loc='upper left')
plt.show()

# %%
plt.plot(history_t_kl_2.history['accuracy'])
plt.plot(history_r_kl_2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Tanh', 'RELU'], loc='upper left')
plt.show()

# %% [markdown]
# ###MISC

# %%
h1 = model_6.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3504 - accuracy: 0.8744

# %%
h2 = model_7.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3421 - accuracy: 0.8776

# %%
h3 = model_8.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3819 - accuracy: 0.8705

# %%
h4 = model_s_1.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3378 - accuracy: 0.8786

# %%
h5 = model_s_2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3561 - accuracy: 0.8739

# %%
h6 = model_s_3.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3978 - accuracy: 0.8681

# %%
h7 = model_t_1.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3477 - accuracy: 0.8738

# %%
h8 = model_t_2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3425 - accuracy: 0.8737

# %%
h9 = model_t_3.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3932 - accuracy: 0.8618

# %%
h10 = model_r_kl_1.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3602 - accuracy: 0.8736

# %%
h11 = model_r_kl_2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3983 - accuracy: 0.8657

# %%
h12 = model_s_kl_1.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3704 - accuracy: 0.8702

# %%
h13 = model_s_kl_2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6669 - accuracy: 0.7325

# %%
h14 = model_t_kl_1.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3722 - accuracy: 0.8693

# %%
h15 = model_t_kl_2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4080 - accuracy: 0.8591

# %%
h16 = model_t_kl_3.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3787 - accuracy: 0.8673
